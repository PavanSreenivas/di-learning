# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Top1000IMDbMovies.csv')

# %%
print(df.to_string())
# Out:
#      Rank                                                            Movie Name  Year of Release  Watch Time  Movie Rating  Metascore of movie   Gross      Votes                                                                                                                                                                                                                                                                                                              Description
# 0       0                                              The Shawshank Redemption             1994         142           9.3                82.0   28.34  27,77,378                                                                                                                                                                              Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.
# ...

# %%
df
# Out:
#      Rank                       Movie Name  Year of Release  Watch Time  \
# 0       0         The Shawshank Redemption             1994         142
# 1       1                    The Godfather             1972         175
# 2       2                  The Dark Knight             2008         152
# 3       3                 Schindler's List             1993         195
# 4       4                     12 Angry Men             1957          96
# ..    ...                              ...              ...         ...
# 995   995                        Philomena             2013          98
# 996   996  Un long dimanche de fiançailles             2004         133
# 997   997                            Shine             1996         105
# 998   998                The Invisible Man             1933          71
# 999   999                        Celda 211             2009         113
#
#      Movie Rating  Metascore of movie   Gross      Votes  \
# ...

# %%
df.head()
# Out:
#    Rank                Movie Name  Year of Release  Watch Time  Movie Rating  \
# 0     0  The Shawshank Redemption             1994         142           9.3
# 1     1             The Godfather             1972         175           9.2
# 2     2           The Dark Knight             2008         152           9.0
# 3     3          Schindler's List             1993         195           9.0
# 4     4              12 Angry Men             1957          96           9.0
#
#    Metascore of movie   Gross      Votes  \
# 0                82.0   28.34  27,77,378
# 1               100.0  134.97  19,33,588
# 2                84.0  534.86  27,54,087
# 3                95.0   96.90  13,97,886
# 4                97.0    4.36   8,24,211
#
#                                          Description
# 0  Over the course of several years, two convicts...
# 1  Don Vito Corleone, head of a mafia family, dec...
# 2  When the menace known as the Joker wreaks havo...
# ...

# %%
df.tail()
# Out:
#      Rank                       Movie Name  Year of Release  Watch Time  \
# 995   995                        Philomena             2013          98
# 996   996  Un long dimanche de fiançailles             2004         133
# 997   997                            Shine             1996         105
# 998   998                The Invisible Man             1933          71
# 999   999                        Celda 211             2009         113
#
#      Movie Rating  Metascore of movie  Gross     Votes  \
# 995           7.6                77.0  37.71  1,02,336
# 996           7.6                76.0   6.17    75,004
# 997           7.6                87.0  35.81    55,589
# 998           7.6                87.0    NaN    37,822
# 999           7.6                 NaN    NaN    69,464
#
#                                            Description
# 995  A world-weary political journalist picks up th...
# 996  Tells the story of a young woman's relentless ...
# ...

# %%
print(df.describe())
# Out:
#               Rank  Year of Release   Watch Time  Movie Rating  \
# count  1000.000000      1000.000000  1000.000000   1000.000000
# mean    499.500000      1991.666000   124.253000      7.970200
# std     288.819436        24.188045    28.800355      0.275732
# min       0.000000      1920.000000    45.000000      7.600000
# 25%     249.750000      1975.000000   103.000000      7.800000
# 50%     499.500000      1999.000000   120.000000      7.900000
# 75%     749.250000      2011.000000   139.000000      8.100000
# max     999.000000      2023.000000   321.000000      9.300000
#
#        Metascore of movie       Gross
# count          845.000000  838.000000
# mean            79.011834   73.016014
# std             11.973800  115.068316
# min             28.000000    0.000000
# 25%             71.000000    3.367500
# 50%             80.000000   25.475000
# 75%             88.000000   96.945000
# max            100.000000  936.660000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Movie Name          1000 non-null   object
#  2   Year of Release     1000 non-null   int64
#  3   Watch Time          1000 non-null   int64
#  4   Movie Rating        1000 non-null   float64
#  5   Metascore of movie  845 non-null    float64
#  6   Gross               838 non-null    float64
#  7   Votes               1000 non-null   object
#  8   Description         1000 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 70.4+ KB
# None

# %%
print(df.iloc[87])
# Out:
# Rank                                                                 87
# Movie Name                                                       Kaithi
# Year of Release                                                    2019
# Watch Time                                                          145
# Movie Rating                                                        8.4
# Metascore of movie                                                  NaN
# Gross                                                               NaN
# Votes                                                            36,952
# Description           Dilli, an ex-convict, endeavours to meet his d...
# Name: 87, dtype: object

# %%
df.loc[[10,143, 189, 329, 849], ['Movie Name', 'Movie Rating', "Gross"]]
# Out:
#                  Movie Name  Movie Rating  Gross
# 10               Fight Club           8.8  37.03
# 143  No Country for Old Men           8.2  74.28
# 189                Drishyam           8.2   0.74
# 329      La Grande Illusion           8.1   0.17
# 849               Malcolm X           7.7  48.17

# %%
df.dtypes
# Out:
# Rank                    int64
# Movie Name             object
# Year of Release         int64
# Watch Time              int64
# Movie Rating          float64
# Metascore of movie    float64
# Gross                 float64
# Votes                  object
# Description            object
# dtype: object

# %%
df.columns = [column.replace(" ","_") for column in df.columns]
querydf = df.copy()
querydf.query("Year_of_Release == 1999", inplace = True)
querydf
# Out:
#      Rank                          Movie_Name  Year_of_Release  Watch_Time  \
# 10     10                          Fight Club             1999         139
# 21     21                          The Matrix             1999         136
# 29     29                      The Green Mile             1999         189
# 95     95                     American Beauty             1999         122
# 157   157                     The Sixth Sense             1999         107
# 266   266                      The Iron Giant             1999          86
# 336   336                           Sarfarosh             1999         174
# 367   367                            Magnolia             1999         188
# 418   418                  The Straight Story             1999         112
# 510   510                         Toy Story 2             1999          92
# 676   676                         The Insider             1999         157
# ...

# %%
querydf2 = df.copy()
querydf2 = querydf2.loc[(querydf2['Year_of_Release'] > 1979) & (querydf2['Year_of_Release'] < 1981)]
querydf2
# Out:
#      Rank                                      Movie_Name  Year_of_Release  \
# 22     22  Star Wars: Episode V - The Empire Strikes Back             1980
# 67     67                                     The Shining             1980
# 171   171                                The Elephant Man             1980
# 254   254                                     Raging Bull             1980
# 490   490                              The Blues Brothers             1980
# 563   563                                       Kagemusha             1980
# 773   773                                       Airplane!             1980
# 841   841                                 Ordinary People             1980
#
#      Watch_Time  Movie_Rating  Metascore_of_movie   Gross      Votes  \
# 22          124           8.7                82.0  290.48  13,33,333
# 67          146           8.4                66.0   44.02  10,60,625
# 171         124           8.2                78.0  156.00   2,50,169
# ...

# %%
import matplotlib.pyplot as plt
plotdf = df.copy()
plotdf  = plotdf.plot(kind = 'scatter' , x = 'Year_of_Release', y = 'Watch_Time')
plt.show()

# %%
df.dtypes
# Out:
# Rank                    int64
# Movie_Name             object
# Year_of_Release         int64
# Watch_Time              int64
# Movie_Rating          float64
# Metascore_of_movie    float64
# Gross                 float64
# Votes                  object
# Description            object
# dtype: object

# %%
df["Gross"] = pd.to_numeric(df["Gross"])

# %%
df.dtypes
# Out:
# Rank                    int64
# Movie_Name             object
# Year_of_Release         int64
# Watch_Time              int64
# Movie_Rating          float64
# Metascore_of_movie    float64
# Gross                 float64
# Votes                  object
# Description            object
# dtype: object

# %%
ndf = df.copy()
ndf = ndf.loc[(ndf['Year_of_Release'] > 1983) & (ndf['Year_of_Release'] < 1986)]
bargraph = ndf.plot.bar(x = 'Movie_Rating', y = 'Gross', fontsize='9')

# %%
df["Votes"] = pd.to_numeric(df["Votes"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "27,77,378"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 df["Votes"] = pd.to_numeric(df["Votes"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# ...

# %%
df['Votes'] = df['Votes'].str.replace(',','')

# %%
df
# Out:
#      Rank                       Movie_Name  Year_of_Release  Watch_Time  \
# 0       0         The Shawshank Redemption             1994         142
# 1       1                    The Godfather             1972         175
# 2       2                  The Dark Knight             2008         152
# 3       3                 Schindler's List             1993         195
# 4       4                     12 Angry Men             1957          96
# ..    ...                              ...              ...         ...
# 995   995                        Philomena             2013          98
# 996   996  Un long dimanche de fiançailles             2004         133
# 997   997                            Shine             1996         105
# 998   998                The Invisible Man             1933          71
# 999   999                        Celda 211             2009         113
#
#      Movie_Rating  Metascore_of_movie   Gross    Votes  \
# ...

# %%
df["Votes"] = pd.to_numeric(df["Votes"])

# %%
df.dtypes
# Out:
# Rank                    int64
# Movie_Name             object
# Year_of_Release         int64
# Watch_Time              int64
# Movie_Rating          float64
# Metascore_of_movie    float64
# Gross                 float64
# Votes                   int64
# Description            object
# dtype: object
